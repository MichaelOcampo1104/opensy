# %%
import openseespywin as ops
import opsvis as opsv 
import numpy as np
import ipywidgets as widgets
import os
import matplotlib.pyplot as plt
import math
import opstool as opst
import time as tt

# %%
import sys
sys.path.append('Data')
import functions.solver_function as SF
import importlib
importlib.reload(SF)
from functions.solver_function import *

# %%
opst.add_ops_hints_file()
# Out:
# OPSTOOL :: opensees.pyi file has been created to
# C:\Users\micha\miniconda3\envs\blue_env\Lib\site-packages\openseespywin\opensees.pyi!

# %%
convert_tcl = 'no'
if(convert_tcl=="yes"):
    opst.pre.tcl2py(input_file='FreeFieldEffective.tcl',
                output_file='FreeFieldEffective.py',
                prefix="ops")

# %%
length_unit = "m"  # base unit
force_unit = "KN"  # base unit

UNIT = opst.pre.UnitSystem(length=length_unit, force=force_unit)

print("Length:", UNIT.mm, UNIT.mm2, UNIT.cm, UNIT.m,)
print("Force", UNIT.N, UNIT.kN, )
print("Stress", UNIT.MPa, UNIT.kPa, UNIT.Pa, )
print("Mass", UNIT.g, UNIT.kg, UNIT.ton)
print(UNIT)
# Out:
# Length: 0.001 1e-06 0.01 1
# Force 0.001 1
# Stress 1000.0 1.0 0.001
# Mass 1e-06 0.001 1.0
# <UnitSystem: length='m', force='kn', time='sec' (142390171899)>

# %%
ops.wipe()
ops.model('BasicBuilder', '-ndm', 2, '-ndf', 3)
ops.node(1, 0.0, 0.0)
print('file1d983367830', '1  0.0  0.0')
ops.node(7, 0.0, 0.5)
print('file1d983367830', '7  0.0  0.5')
ops.node(13, 0.0, 1.0)
print('file1d983367830', '13  0.0  1.0')
ops.node(19, 0.0, 1.5)
print('file1d983367830', '19  0.0  1.5')
ops.node(25, 0.0, 2.0)
print('file1d983367830', '25  0.0  2.0')
ops.node(31, 0.0, 2.5)
print('file1d983367830', '31  0.0  2.5')
ops.node(37, 0.0, 3.0)
print('file1d983367830', '37  0.0  3.0')
ops.node(43, 0.0, 3.5)
print('file1d983367830', '43  0.0  3.5')
ops.node(49, 0.0, 4.0)
print('file1d983367830', '49  0.0  4.0')
ops.node(55, 0.0, 4.5)
print('file1d983367830', '55  0.0  4.5')
ops.node(61, 0.0, 5.0)
print('file1d983367830', '61  0.0  5.0')
ops.node(67, 0.0, 5.5)
print('file1d983367830', '67  0.0  5.5')
ops.node(73, 0.0, 6.0)
print('file1d983367830', '73  0.0  6.0')
ops.node(79, 0.0, 6.5)
print('file1d983367830', '79  0.0  6.5')
ops.node(85, 0.0, 7.0)
print('file1d983367830', '85  0.0  7.0')
ops.node(91, 0.0, 7.5)
print('file1d983367830', '91  0.0  7.5')
ops.node(97, 0.0, 8.0)
print('file1d983367830', '97  0.0  8.0')
ops.node(103, 0.0, 8.5)
print('file1d983367830', '103  0.0  8.5')
ops.node(109, 0.0, 9.0)
print('file1d983367830', '109  0.0  9.0')
ops.node(115, 0.0, 9.5)
print('file1d983367830', '115  0.0  9.5')
ops.node(121, 0.0, 10.0)
print('file1d983367830', '121  0.0  10.0')
ops.node(127, 0.0, 10.5)
print('file1d983367830', '127  0.0  10.5')
ops.node(133, 0.0, 11.0)
print('file1d983367830', '133  0.0  11.0')
ops.node(139, 0.0, 11.5)
print('file1d983367830', '139  0.0  11.5')
ops.node(145, 0.0, 12.0)
print('file1d983367830', '145  0.0  12.0')
ops.node(151, 0.0, 12.5)
print('file1d983367830', '151  0.0  12.5')
ops.node(157, 0.0, 13.0)
print('file1d983367830', '157  0.0  13.0')
ops.node(163, 0.0, 13.5)
print('file1d983367830', '163  0.0  13.5')
ops.node(169, 0.0, 14.0)
print('file1d983367830', '169  0.0  14.0')
ops.node(175, 0.0, 14.5)
print('file1d983367830', '175  0.0  14.5')
ops.node(181, 0.0, 15.0)
print('file1d983367830', '181  0.0  15.0')
ops.node(187, 0.0, 15.5)
print('file1d983367830', '187  0.0  15.5')
ops.node(193, 0.0, 16.0)
print('file1d983367830', '193  0.0  16.0')
ops.node(199, 0.0, 16.5)
print('file1d983367830', '199  0.0  16.5')
ops.node(205, 0.0, 17.0)
print('file1d983367830', '205  0.0  17.0')
ops.node(211, 0.0, 17.5)
print('file1d983367830', '211  0.0  17.5')
ops.node(217, 0.0, 18.0)
print('file1d983367830', '217  0.0  18.0')
ops.node(223, 0.0, 18.5)
print('file1d983367830', '223  0.0  18.5')
ops.node(229, 0.0, 19.0)
print('file1d983367830', '229  0.0  19.0')
ops.node(235, 0.0, 19.5)
print('file1d983367830', '235  0.0  19.5')
ops.node(241, 0.0, 20.0)
print('file1d983367830', '241  0.0  20.0')
ops.node(3, 2.0, 0.0)
print('file1d983367830', '3  2.0  0.0')
ops.node(9, 2.0, 0.5)
print('file1d983367830', '9  2.0  0.5')
ops.node(15, 2.0, 1.0)
print('file1d983367830', '15  2.0  1.0')
ops.node(21, 2.0, 1.5)
print('file1d983367830', '21  2.0  1.5')
ops.node(27, 2.0, 2.0)
print('file1d983367830', '27  2.0  2.0')
ops.node(33, 2.0, 2.5)
print('file1d983367830', '33  2.0  2.5')
ops.node(39, 2.0, 3.0)
print('file1d983367830', '39  2.0  3.0')
ops.node(45, 2.0, 3.5)
print('file1d983367830', '45  2.0  3.5')
ops.node(51, 2.0, 4.0)
print('file1d983367830', '51  2.0  4.0')
ops.node(57, 2.0, 4.5)
print('file1d983367830', '57  2.0  4.5')
ops.node(63, 2.0, 5.0)
print('file1d983367830', '63  2.0  5.0')
ops.node(69, 2.0, 5.5)
print('file1d983367830', '69  2.0  5.5')
ops.node(75, 2.0, 6.0)
print('file1d983367830', '75  2.0  6.0')
ops.node(81, 2.0, 6.5)
print('file1d983367830', '81  2.0  6.5')
ops.node(87, 2.0, 7.0)
print('file1d983367830', '87  2.0  7.0')
ops.node(93, 2.0, 7.5)
print('file1d983367830', '93  2.0  7.5')
ops.node(99, 2.0, 8.0)
print('file1d983367830', '99  2.0  8.0')
ops.node(105, 2.0, 8.5)
print('file1d983367830', '105  2.0  8.5')
ops.node(111, 2.0, 9.0)
print('file1d983367830', '111  2.0  9.0')
ops.node(117, 2.0, 9.5)
print('file1d983367830', '117  2.0  9.5')
ops.node(123, 2.0, 10.0)
print('file1d983367830', '123  2.0  10.0')
ops.node(129, 2.0, 10.5)
print('file1d983367830', '129  2.0  10.5')
ops.node(135, 2.0, 11.0)
print('file1d983367830', '135  2.0  11.0')
ops.node(141, 2.0, 11.5)
print('file1d983367830', '141  2.0  11.5')
ops.node(147, 2.0, 12.0)
print('file1d983367830', '147  2.0  12.0')
ops.node(153, 2.0, 12.5)
print('file1d983367830', '153  2.0  12.5')
ops.node(159, 2.0, 13.0)
print('file1d983367830', '159  2.0  13.0')
ops.node(165, 2.0, 13.5)
print('file1d983367830', '165  2.0  13.5')
ops.node(171, 2.0, 14.0)
print('file1d983367830', '171  2.0  14.0')
ops.node(177, 2.0, 14.5)
print('file1d983367830', '177  2.0  14.5')
ops.node(183, 2.0, 15.0)
print('file1d983367830', '183  2.0  15.0')
ops.node(189, 2.0, 15.5)
print('file1d983367830', '189  2.0  15.5')
ops.node(195, 2.0, 16.0)
print('file1d983367830', '195  2.0  16.0')
ops.node(201, 2.0, 16.5)
print('file1d983367830', '201  2.0  16.5')
ops.node(207, 2.0, 17.0)
print('file1d983367830', '207  2.0  17.0')
ops.node(213, 2.0, 17.5)
print('file1d983367830', '213  2.0  17.5')
ops.node(219, 2.0, 18.0)
print('file1d983367830', '219  2.0  18.0')
ops.node(225, 2.0, 18.5)
print('file1d983367830', '225  2.0  18.5')
ops.node(231, 2.0, 19.0)
print('file1d983367830', '231  2.0  19.0')
ops.node(237, 2.0, 19.5)
print('file1d983367830', '237  2.0  19.5')
ops.node(243, 2.0, 20.0)
print('file1d983367830', '243  2.0  20.0')
ops.node(247, 0.0, 20.5)
print('file1d983367830', '247  0.0  20.5')
ops.node(253, 0.0, 21.0)
print('file1d983367830', '253  0.0  21.0')
ops.node(259, 0.0, 21.5)
print('file1d983367830', '259  0.0  21.5')
ops.node(265, 0.0, 22.0)
print('file1d983367830', '265  0.0  22.0')
ops.node(271, 0.0, 22.5)
print('file1d983367830', '271  0.0  22.5')
ops.node(277, 0.0, 23.0)
print('file1d983367830', '277  0.0  23.0')
ops.node(283, 0.0, 23.5)
print('file1d983367830', '283  0.0  23.5')
ops.node(289, 0.0, 24.0)
print('file1d983367830', '289  0.0  24.0')
ops.node(295, 0.0, 24.5)
print('file1d983367830', '295  0.0  24.5')
ops.node(301, 0.0, 25.0)
print('file1d983367830', '301  0.0  25.0')
ops.node(307, 0.0, 25.5)
print('file1d983367830', '307  0.0  25.5')
ops.node(313, 0.0, 26.0)
print('file1d983367830', '313  0.0  26.0')
ops.node(319, 0.0, 26.5)
print('file1d983367830', '319  0.0  26.5')
ops.node(325, 0.0, 27.0)
print('file1d983367830', '325  0.0  27.0')
ops.node(331, 0.0, 27.5)
print('file1d983367830', '331  0.0  27.5')
ops.node(337, 0.0, 28.0)
print('file1d983367830', '337  0.0  28.0')
ops.node(249, 2.0, 20.5)
print('file1d983367830', '249  2.0  20.5')
ops.node(255, 2.0, 21.0)
print('file1d983367830', '255  2.0  21.0')
ops.node(261, 2.0, 21.5)
print('file1d983367830', '261  2.0  21.5')
ops.node(267, 2.0, 22.0)
print('file1d983367830', '267  2.0  22.0')
ops.node(273, 2.0, 22.5)
print('file1d983367830', '273  2.0  22.5')
ops.node(279, 2.0, 23.0)
print('file1d983367830', '279  2.0  23.0')
ops.node(285, 2.0, 23.5)
print('file1d983367830', '285  2.0  23.5')
ops.node(291, 2.0, 24.0)
print('file1d983367830', '291  2.0  24.0')
ops.node(297, 2.0, 24.5)
print('file1d983367830', '297  2.0  24.5')
ops.node(303, 2.0, 25.0)
print('file1d983367830', '303  2.0  25.0')
ops.node(309, 2.0, 25.5)
print('file1d983367830', '309  2.0  25.5')
ops.node(315, 2.0, 26.0)
print('file1d983367830', '315  2.0  26.0')
ops.node(321, 2.0, 26.5)
print('file1d983367830', '321  2.0  26.5')
ops.node(327, 2.0, 27.0)
print('file1d983367830', '327  2.0  27.0')
ops.node(333, 2.0, 27.5)
print('file1d983367830', '333  2.0  27.5')
ops.node(339, 2.0, 28.0)
print('file1d983367830', '339  2.0  28.0')
ops.node(343, 0.0, 28.5)
print('file1d983367830', '343  0.0  28.5')
ops.node(349, 0.0, 29.0)
print('file1d983367830', '349  0.0  29.0')
ops.node(355, 0.0, 29.5)
print('file1d983367830', '355  0.0  29.5')
ops.node(361, 0.0, 30.0)
print('file1d983367830', '361  0.0  30.0')
ops.node(345, 2.0, 28.5)
print('file1d983367830', '345  2.0  28.5')
ops.node(351, 2.0, 29.0)
print('file1d983367830', '351  2.0  29.0')
ops.node(357, 2.0, 29.5)
print('file1d983367830', '357  2.0  29.5')
ops.node(363, 2.0, 30.0)
print('file1d983367830', '363  2.0  30.0')
print('Finished creating all -ndf 3 nodes...')
# Out:
# file1d983367830 1  0.0  0.0
# file1d983367830 7  0.0  0.5
# file1d983367830 13  0.0  1.0
# file1d983367830 19  0.0  1.5
# file1d983367830 25  0.0  2.0
# file1d983367830 31  0.0  2.5
# file1d983367830 37  0.0  3.0
# file1d983367830 43  0.0  3.5
# file1d983367830 49  0.0  4.0
# file1d983367830 55  0.0  4.5
# file1d983367830 61  0.0  5.0
# file1d983367830 67  0.0  5.5
# file1d983367830 73  0.0  6.0
# file1d983367830 79  0.0  6.5
# file1d983367830 85  0.0  7.0
# file1d983367830 91  0.0  7.5
# file1d983367830 97  0.0  8.0
# file1d983367830 103  0.0  8.5
# file1d983367830 109  0.0  9.0
# file1d983367830 115  0.0  9.5
# file1d983367830 121  0.0  10.0
# file1d983367830 127  0.0  10.5
# file1d983367830 133  0.0  11.0
# file1d983367830 139  0.0  11.5
# file1d983367830 145  0.0  12.0
# file1d983367830 151  0.0  12.5
# file1d983367830 157  0.0  13.0
# file1d983367830 163  0.0  13.5
# file1d983367830 169  0.0  14.0
# file1d983367830 175  0.0  14.5
# file1d983367830 181  0.0  15.0
# ...

# %%
ops.fix(337, 0, 0, 1)
ops.fix(339, 0, 0, 1)
ops.fix(343, 0, 0, 1)
ops.fix(349, 0, 0, 1)
ops.fix(355, 0, 0, 1)
ops.fix(361, 0, 0, 1)
ops.fix(345, 0, 0, 1)
ops.fix(351, 0, 0, 1)
ops.fix(357, 0, 0, 1)
ops.fix(363, 0, 0, 1)
ops.fix(1, 0, 1, 0)
ops.fix(3, 0, 1, 0)
print('Finished creating all -ndf 3 boundary conditions...')
# Out:
# Finished creating all -ndf 3 boundary conditions...

# %%
ops.equalDOF(1, 3, 1, 2)
ops.equalDOF(7, 9, 1, 2)
ops.equalDOF(13, 15, 1, 2)
ops.equalDOF(19, 21, 1, 2)
ops.equalDOF(25, 27, 1, 2)
ops.equalDOF(31, 33, 1, 2)
ops.equalDOF(37, 39, 1, 2)
ops.equalDOF(43, 45, 1, 2)
ops.equalDOF(49, 51, 1, 2)
ops.equalDOF(55, 57, 1, 2)
ops.equalDOF(61, 63, 1, 2)
ops.equalDOF(67, 69, 1, 2)
ops.equalDOF(73, 75, 1, 2)
ops.equalDOF(79, 81, 1, 2)
ops.equalDOF(85, 87, 1, 2)
ops.equalDOF(91, 93, 1, 2)
ops.equalDOF(97, 99, 1, 2)
ops.equalDOF(103, 105, 1, 2)
ops.equalDOF(109, 111, 1, 2)
ops.equalDOF(115, 117, 1, 2)
ops.equalDOF(121, 123, 1, 2)
ops.equalDOF(127, 129, 1, 2)
ops.equalDOF(133, 135, 1, 2)
ops.equalDOF(139, 141, 1, 2)
ops.equalDOF(145, 147, 1, 2)
ops.equalDOF(151, 153, 1, 2)
ops.equalDOF(157, 159, 1, 2)
ops.equalDOF(163, 165, 1, 2)
ops.equalDOF(169, 171, 1, 2)
ops.equalDOF(175, 177, 1, 2)
ops.equalDOF(181, 183, 1, 2)
ops.equalDOF(187, 189, 1, 2)
ops.equalDOF(193, 195, 1, 2)
ops.equalDOF(199, 201, 1, 2)
ops.equalDOF(205, 207, 1, 2)
ops.equalDOF(211, 213, 1, 2)
ops.equalDOF(217, 219, 1, 2)
ops.equalDOF(223, 225, 1, 2)
ops.equalDOF(229, 231, 1, 2)
ops.equalDOF(235, 237, 1, 2)
ops.equalDOF(241, 243, 1, 2)
ops.equalDOF(247, 249, 1, 2)
ops.equalDOF(253, 255, 1, 2)
ops.equalDOF(259, 261, 1, 2)
ops.equalDOF(265, 267, 1, 2)
ops.equalDOF(271, 273, 1, 2)
ops.equalDOF(277, 279, 1, 2)
ops.equalDOF(283, 285, 1, 2)
ops.equalDOF(289, 291, 1, 2)
ops.equalDOF(295, 297, 1, 2)
ops.equalDOF(301, 303, 1, 2)
ops.equalDOF(307, 309, 1, 2)
ops.equalDOF(313, 315, 1, 2)
ops.equalDOF(319, 321, 1, 2)
ops.equalDOF(325, 327, 1, 2)
ops.equalDOF(331, 333, 1, 2)
ops.equalDOF(337, 339, 1, 2)
ops.equalDOF(343, 345, 1, 2)
ops.equalDOF(349, 351, 1, 2)
ops.equalDOF(355, 357, 1, 2)
ops.equalDOF(361, 363, 1, 2)
print('Finished creating equalDOF for pore pressure nodes...')
# Out:
# Finished creating equalDOF for pore pressure nodes...

# %%
opst.vis.plotly.plot_model(show_node_numbering=False, show_ele_numbering=False, show_nodal_loads = False)

# %%
ops.model('BasicBuilder', '-ndm', 2, '-ndf', 2)
ops.node(2, 1.0, 0.0)
ops.node(5, 1.0, 0.25)
ops.node(8, 1.0, 0.5)
ops.node(11, 1.0, 0.75)
ops.node(14, 1.0, 1.0)
ops.node(17, 1.0, 1.25)
ops.node(20, 1.0, 1.5)
ops.node(23, 1.0, 1.75)
ops.node(26, 1.0, 2.0)
ops.node(29, 1.0, 2.25)
ops.node(32, 1.0, 2.5)
ops.node(35, 1.0, 2.75)
ops.node(38, 1.0, 3.0)
ops.node(41, 1.0, 3.25)
ops.node(44, 1.0, 3.5)
ops.node(47, 1.0, 3.75)
ops.node(50, 1.0, 4.0)
ops.node(53, 1.0, 4.25)
ops.node(56, 1.0, 4.5)
ops.node(59, 1.0, 4.75)
ops.node(62, 1.0, 5.0)
ops.node(65, 1.0, 5.25)
ops.node(68, 1.0, 5.5)
ops.node(71, 1.0, 5.75)
ops.node(74, 1.0, 6.0)
ops.node(77, 1.0, 6.25)
ops.node(80, 1.0, 6.5)
ops.node(83, 1.0, 6.75)
ops.node(86, 1.0, 7.0)
ops.node(89, 1.0, 7.25)
ops.node(92, 1.0, 7.5)
ops.node(95, 1.0, 7.75)
ops.node(98, 1.0, 8.0)
ops.node(101, 1.0, 8.25)
ops.node(104, 1.0, 8.5)
ops.node(107, 1.0, 8.75)
ops.node(110, 1.0, 9.0)
ops.node(113, 1.0, 9.25)
ops.node(116, 1.0, 9.5)
ops.node(119, 1.0, 9.75)
ops.node(122, 1.0, 10.0)
ops.node(125, 1.0, 10.25)
ops.node(128, 1.0, 10.5)
ops.node(131, 1.0, 10.75)
ops.node(134, 1.0, 11.0)
ops.node(137, 1.0, 11.25)
ops.node(140, 1.0, 11.5)
ops.node(143, 1.0, 11.75)
ops.node(146, 1.0, 12.0)
ops.node(149, 1.0, 12.25)
ops.node(152, 1.0, 12.5)
ops.node(155, 1.0, 12.75)
ops.node(158, 1.0, 13.0)
ops.node(161, 1.0, 13.25)
ops.node(164, 1.0, 13.5)
ops.node(167, 1.0, 13.75)
ops.node(170, 1.0, 14.0)
ops.node(173, 1.0, 14.25)
ops.node(176, 1.0, 14.5)
ops.node(179, 1.0, 14.75)
ops.node(182, 1.0, 15.0)
ops.node(185, 1.0, 15.25)
ops.node(188, 1.0, 15.5)
ops.node(191, 1.0, 15.75)
ops.node(194, 1.0, 16.0)
ops.node(197, 1.0, 16.25)
ops.node(200, 1.0, 16.5)
ops.node(203, 1.0, 16.75)
ops.node(206, 1.0, 17.0)
ops.node(209, 1.0, 17.25)
ops.node(212, 1.0, 17.5)
ops.node(215, 1.0, 17.75)
ops.node(218, 1.0, 18.0)
ops.node(221, 1.0, 18.25)
ops.node(224, 1.0, 18.5)
ops.node(227, 1.0, 18.75)
ops.node(230, 1.0, 19.0)
ops.node(233, 1.0, 19.25)
ops.node(236, 1.0, 19.5)
ops.node(239, 1.0, 19.75)
ops.node(242, 1.0, 20.0)
ops.node(245, 1.0, 20.25)
ops.node(248, 1.0, 20.5)
ops.node(251, 1.0, 20.75)
ops.node(254, 1.0, 21.0)
ops.node(257, 1.0, 21.25)
ops.node(260, 1.0, 21.5)
ops.node(263, 1.0, 21.75)
ops.node(266, 1.0, 22.0)
ops.node(269, 1.0, 22.25)
ops.node(272, 1.0, 22.5)
ops.node(275, 1.0, 22.75)
ops.node(278, 1.0, 23.0)
ops.node(281, 1.0, 23.25)
ops.node(284, 1.0, 23.5)
ops.node(287, 1.0, 23.75)
ops.node(290, 1.0, 24.0)
ops.node(293, 1.0, 24.25)
ops.node(296, 1.0, 24.5)
ops.node(299, 1.0, 24.75)
ops.node(302, 1.0, 25.0)
ops.node(305, 1.0, 25.25)
ops.node(308, 1.0, 25.5)
ops.node(311, 1.0, 25.75)
ops.node(314, 1.0, 26.0)
ops.node(317, 1.0, 26.25)
ops.node(320, 1.0, 26.5)
ops.node(323, 1.0, 26.75)
ops.node(326, 1.0, 27.0)
ops.node(329, 1.0, 27.25)
ops.node(332, 1.0, 27.5)
ops.node(335, 1.0, 27.75)
ops.node(338, 1.0, 28.0)
ops.node(341, 1.0, 28.25)
ops.node(344, 1.0, 28.5)
ops.node(347, 1.0, 28.75)
ops.node(350, 1.0, 29.0)
ops.node(353, 1.0, 29.25)
ops.node(356, 1.0, 29.5)
ops.node(359, 1.0, 29.75)
ops.node(362, 1.0, 30.0)
ops.node(4, 0.0, 0.25)
ops.node(6, 2.0, 0.25)
ops.node(10, 0.0, 0.75)
ops.node(12, 2.0, 0.75)
ops.node(16, 0.0, 1.25)
ops.node(18, 2.0, 1.25)
ops.node(22, 0.0, 1.75)
ops.node(24, 2.0, 1.75)
ops.node(28, 0.0, 2.25)
ops.node(30, 2.0, 2.25)
ops.node(34, 0.0, 2.75)
ops.node(36, 2.0, 2.75)
ops.node(40, 0.0, 3.25)
ops.node(42, 2.0, 3.25)
ops.node(46, 0.0, 3.75)
ops.node(48, 2.0, 3.75)
ops.node(52, 0.0, 4.25)
ops.node(54, 2.0, 4.25)
ops.node(58, 0.0, 4.75)
ops.node(60, 2.0, 4.75)
ops.node(64, 0.0, 5.25)
ops.node(66, 2.0, 5.25)
ops.node(70, 0.0, 5.75)
ops.node(72, 2.0, 5.75)
ops.node(76, 0.0, 6.25)
ops.node(78, 2.0, 6.25)
ops.node(82, 0.0, 6.75)
ops.node(84, 2.0, 6.75)
ops.node(88, 0.0, 7.25)
ops.node(90, 2.0, 7.25)
ops.node(94, 0.0, 7.75)
ops.node(96, 2.0, 7.75)
ops.node(100, 0.0, 8.25)
ops.node(102, 2.0, 8.25)
ops.node(106, 0.0, 8.75)
ops.node(108, 2.0, 8.75)
ops.node(112, 0.0, 9.25)
ops.node(114, 2.0, 9.25)
ops.node(118, 0.0, 9.75)
ops.node(120, 2.0, 9.75)
ops.node(124, 0.0, 10.25)
ops.node(126, 2.0, 10.25)
ops.node(130, 0.0, 10.75)
ops.node(132, 2.0, 10.75)
ops.node(136, 0.0, 11.25)
ops.node(138, 2.0, 11.25)
ops.node(142, 0.0, 11.75)
ops.node(144, 2.0, 11.75)
ops.node(148, 0.0, 12.25)
ops.node(150, 2.0, 12.25)
ops.node(154, 0.0, 12.75)
ops.node(156, 2.0, 12.75)
ops.node(160, 0.0, 13.25)
ops.node(162, 2.0, 13.25)
ops.node(166, 0.0, 13.75)
ops.node(168, 2.0, 13.75)
ops.node(172, 0.0, 14.25)
ops.node(174, 2.0, 14.25)
ops.node(178, 0.0, 14.75)
ops.node(180, 2.0, 14.75)
ops.node(184, 0.0, 15.25)
ops.node(186, 2.0, 15.25)
ops.node(190, 0.0, 15.75)
ops.node(192, 2.0, 15.75)
ops.node(196, 0.0, 16.25)
ops.node(198, 2.0, 16.25)
ops.node(202, 0.0, 16.75)
ops.node(204, 2.0, 16.75)
ops.node(208, 0.0, 17.25)
ops.node(210, 2.0, 17.25)
ops.node(214, 0.0, 17.75)
ops.node(216, 2.0, 17.75)
ops.node(220, 0.0, 18.25)
ops.node(222, 2.0, 18.25)
ops.node(226, 0.0, 18.75)
ops.node(228, 2.0, 18.75)
ops.node(232, 0.0, 19.25)
ops.node(234, 2.0, 19.25)
ops.node(238, 0.0, 19.75)
ops.node(240, 2.0, 19.75)
ops.node(244, 0.0, 20.25)
ops.node(246, 2.0, 20.25)
ops.node(250, 0.0, 20.75)
ops.node(252, 2.0, 20.75)
ops.node(256, 0.0, 21.25)
ops.node(258, 2.0, 21.25)
ops.node(262, 0.0, 21.75)
ops.node(264, 2.0, 21.75)
ops.node(268, 0.0, 22.25)
ops.node(270, 2.0, 22.25)
ops.node(274, 0.0, 22.75)
ops.node(276, 2.0, 22.75)
ops.node(280, 0.0, 23.25)
ops.node(282, 2.0, 23.25)
ops.node(286, 0.0, 23.75)
ops.node(288, 2.0, 23.75)
ops.node(292, 0.0, 24.25)
ops.node(294, 2.0, 24.25)
ops.node(298, 0.0, 24.75)
ops.node(300, 2.0, 24.75)
ops.node(304, 0.0, 25.25)
ops.node(306, 2.0, 25.25)
ops.node(310, 0.0, 25.75)
ops.node(312, 2.0, 25.75)
ops.node(316, 0.0, 26.25)
ops.node(318, 2.0, 26.25)
ops.node(322, 0.0, 26.75)
ops.node(324, 2.0, 26.75)
ops.node(328, 0.0, 27.25)
ops.node(330, 2.0, 27.25)
ops.node(334, 0.0, 27.75)
ops.node(336, 2.0, 27.75)
ops.node(340, 0.0, 28.25)
ops.node(342, 2.0, 28.25)
ops.node(346, 0.0, 28.75)
ops.node(348, 2.0, 28.75)
ops.node(352, 0.0, 29.25)
ops.node(354, 2.0, 29.25)
ops.node(358, 0.0, 29.75)
ops.node(360, 2.0, 29.75)
print('Finished creating all -ndf 2 nodes...')
# Out:
# Finished creating all -ndf 2 nodes...

# %%
ops.fix(2, 0, 1)

# %%
ops.equalDOF(1, 2, 1, 2)
ops.equalDOF(4, 5, 1, 2)
ops.equalDOF(4, 6, 1, 2)
ops.equalDOF(7, 8, 1, 2)
ops.equalDOF(10, 11, 1, 2)
ops.equalDOF(10, 12, 1, 2)
ops.equalDOF(13, 14, 1, 2)
ops.equalDOF(16, 17, 1, 2)
ops.equalDOF(16, 18, 1, 2)
ops.equalDOF(19, 20, 1, 2)
ops.equalDOF(22, 23, 1, 2)
ops.equalDOF(22, 24, 1, 2)
ops.equalDOF(25, 26, 1, 2)
ops.equalDOF(28, 29, 1, 2)
ops.equalDOF(28, 30, 1, 2)
ops.equalDOF(31, 32, 1, 2)
ops.equalDOF(34, 35, 1, 2)
ops.equalDOF(34, 36, 1, 2)
ops.equalDOF(37, 38, 1, 2)
ops.equalDOF(40, 41, 1, 2)
ops.equalDOF(40, 42, 1, 2)
ops.equalDOF(43, 44, 1, 2)
ops.equalDOF(46, 47, 1, 2)
ops.equalDOF(46, 48, 1, 2)
ops.equalDOF(49, 50, 1, 2)
ops.equalDOF(52, 53, 1, 2)
ops.equalDOF(52, 54, 1, 2)
ops.equalDOF(55, 56, 1, 2)
ops.equalDOF(58, 59, 1, 2)
ops.equalDOF(58, 60, 1, 2)
ops.equalDOF(61, 62, 1, 2)
ops.equalDOF(64, 65, 1, 2)
ops.equalDOF(64, 66, 1, 2)
ops.equalDOF(67, 68, 1, 2)
ops.equalDOF(70, 71, 1, 2)
ops.equalDOF(70, 72, 1, 2)
ops.equalDOF(73, 74, 1, 2)
ops.equalDOF(76, 77, 1, 2)
ops.equalDOF(76, 78, 1, 2)
ops.equalDOF(79, 80, 1, 2)
ops.equalDOF(82, 83, 1, 2)
ops.equalDOF(82, 84, 1, 2)
ops.equalDOF(85, 86, 1, 2)
ops.equalDOF(88, 89, 1, 2)
ops.equalDOF(88, 90, 1, 2)
ops.equalDOF(91, 92, 1, 2)
ops.equalDOF(94, 95, 1, 2)
ops.equalDOF(94, 96, 1, 2)
ops.equalDOF(97, 98, 1, 2)
ops.equalDOF(100, 101, 1, 2)
ops.equalDOF(100, 102, 1, 2)
ops.equalDOF(103, 104, 1, 2)
ops.equalDOF(106, 107, 1, 2)
ops.equalDOF(106, 108, 1, 2)
ops.equalDOF(109, 110, 1, 2)
ops.equalDOF(112, 113, 1, 2)
ops.equalDOF(112, 114, 1, 2)
ops.equalDOF(115, 116, 1, 2)
ops.equalDOF(118, 119, 1, 2)
ops.equalDOF(118, 120, 1, 2)
ops.equalDOF(121, 122, 1, 2)
ops.equalDOF(124, 125, 1, 2)
ops.equalDOF(124, 126, 1, 2)
ops.equalDOF(127, 128, 1, 2)
ops.equalDOF(130, 131, 1, 2)
ops.equalDOF(130, 132, 1, 2)
ops.equalDOF(133, 134, 1, 2)
ops.equalDOF(136, 137, 1, 2)
ops.equalDOF(136, 138, 1, 2)
ops.equalDOF(139, 140, 1, 2)
ops.equalDOF(142, 143, 1, 2)
ops.equalDOF(142, 144, 1, 2)
ops.equalDOF(145, 146, 1, 2)
ops.equalDOF(148, 149, 1, 2)
ops.equalDOF(148, 150, 1, 2)
ops.equalDOF(151, 152, 1, 2)
ops.equalDOF(154, 155, 1, 2)
ops.equalDOF(154, 156, 1, 2)
ops.equalDOF(157, 158, 1, 2)
ops.equalDOF(160, 161, 1, 2)
ops.equalDOF(160, 162, 1, 2)
ops.equalDOF(163, 164, 1, 2)
ops.equalDOF(166, 167, 1, 2)
ops.equalDOF(166, 168, 1, 2)
ops.equalDOF(169, 170, 1, 2)
ops.equalDOF(172, 173, 1, 2)
ops.equalDOF(172, 174, 1, 2)
ops.equalDOF(175, 176, 1, 2)
ops.equalDOF(178, 179, 1, 2)
ops.equalDOF(178, 180, 1, 2)
ops.equalDOF(181, 182, 1, 2)
ops.equalDOF(184, 185, 1, 2)
ops.equalDOF(184, 186, 1, 2)
ops.equalDOF(187, 188, 1, 2)
ops.equalDOF(190, 191, 1, 2)
ops.equalDOF(190, 192, 1, 2)
ops.equalDOF(193, 194, 1, 2)
ops.equalDOF(196, 197, 1, 2)
ops.equalDOF(196, 198, 1, 2)
ops.equalDOF(199, 200, 1, 2)
ops.equalDOF(202, 203, 1, 2)
ops.equalDOF(202, 204, 1, 2)
ops.equalDOF(205, 206, 1, 2)
ops.equalDOF(208, 209, 1, 2)
ops.equalDOF(208, 210, 1, 2)
ops.equalDOF(211, 212, 1, 2)
ops.equalDOF(214, 215, 1, 2)
ops.equalDOF(214, 216, 1, 2)
ops.equalDOF(217, 218, 1, 2)
ops.equalDOF(220, 221, 1, 2)
ops.equalDOF(220, 222, 1, 2)
ops.equalDOF(223, 224, 1, 2)
ops.equalDOF(226, 227, 1, 2)
ops.equalDOF(226, 228, 1, 2)
ops.equalDOF(229, 230, 1, 2)
ops.equalDOF(232, 233, 1, 2)
ops.equalDOF(232, 234, 1, 2)
ops.equalDOF(235, 236, 1, 2)
ops.equalDOF(238, 239, 1, 2)
ops.equalDOF(238, 240, 1, 2)
ops.equalDOF(241, 242, 1, 2)
ops.equalDOF(244, 245, 1, 2)
ops.equalDOF(244, 246, 1, 2)
ops.equalDOF(247, 248, 1, 2)
ops.equalDOF(250, 251, 1, 2)
ops.equalDOF(250, 252, 1, 2)
ops.equalDOF(253, 254, 1, 2)
ops.equalDOF(256, 257, 1, 2)
ops.equalDOF(256, 258, 1, 2)
ops.equalDOF(259, 260, 1, 2)
ops.equalDOF(262, 263, 1, 2)
ops.equalDOF(262, 264, 1, 2)
ops.equalDOF(265, 266, 1, 2)
ops.equalDOF(268, 269, 1, 2)
ops.equalDOF(268, 270, 1, 2)
ops.equalDOF(271, 272, 1, 2)
ops.equalDOF(274, 275, 1, 2)
ops.equalDOF(274, 276, 1, 2)
ops.equalDOF(277, 278, 1, 2)
ops.equalDOF(280, 281, 1, 2)
ops.equalDOF(280, 282, 1, 2)
ops.equalDOF(283, 284, 1, 2)
ops.equalDOF(286, 287, 1, 2)
ops.equalDOF(286, 288, 1, 2)
ops.equalDOF(289, 290, 1, 2)
ops.equalDOF(292, 293, 1, 2)
ops.equalDOF(292, 294, 1, 2)
ops.equalDOF(295, 296, 1, 2)
ops.equalDOF(298, 299, 1, 2)
ops.equalDOF(298, 300, 1, 2)
ops.equalDOF(301, 302, 1, 2)
ops.equalDOF(304, 305, 1, 2)
ops.equalDOF(304, 306, 1, 2)
ops.equalDOF(307, 308, 1, 2)
ops.equalDOF(310, 311, 1, 2)
ops.equalDOF(310, 312, 1, 2)
ops.equalDOF(313, 314, 1, 2)
ops.equalDOF(316, 317, 1, 2)
ops.equalDOF(316, 318, 1, 2)
ops.equalDOF(319, 320, 1, 2)
ops.equalDOF(322, 323, 1, 2)
ops.equalDOF(322, 324, 1, 2)
ops.equalDOF(325, 326, 1, 2)
ops.equalDOF(328, 329, 1, 2)
ops.equalDOF(328, 330, 1, 2)
ops.equalDOF(331, 332, 1, 2)
ops.equalDOF(334, 335, 1, 2)
ops.equalDOF(334, 336, 1, 2)
ops.equalDOF(337, 338, 1, 2)
ops.equalDOF(340, 341, 1, 2)
ops.equalDOF(340, 342, 1, 2)
ops.equalDOF(343, 344, 1, 2)
ops.equalDOF(346, 347, 1, 2)
ops.equalDOF(346, 348, 1, 2)
ops.equalDOF(349, 350, 1, 2)
ops.equalDOF(352, 353, 1, 2)
ops.equalDOF(352, 354, 1, 2)
ops.equalDOF(355, 356, 1, 2)
ops.equalDOF(358, 359, 1, 2)
ops.equalDOF(358, 360, 1, 2)
ops.equalDOF(361, 362, 1, 2)

# %%
ops.nDMaterial('PressureDependMultiYield02', 3, 2, 1.8, 90000.0, 220000.0, 32, 0.1, 101.0, 0.5, 26, 0.067, 0.23, 0.06, 0.27, 20, 5.0, 3.0, 1.0, 0.0, 0.77, 0.9, 0.02, 0.7, 101.0)
ops.nDMaterial('PressureDependMultiYield02', 2, 2, 2.24, 90000.0, 220000.0, 32, 0.1, 101.0, 0.5, 26, 0.067, 0.23, 0.06, 0.27, 20, 5.0, 3.0, 1.0, 0.0, 0.77, 0.9, 0.02, 0.7, 101.0)
ops.nDMaterial('PressureDependMultiYield02', 1, 2, 2.45, 130000.0, 260000.0, 39, 0.1, 101.0, 0.5, 26, 0.01, 0.0, 0.35, 0.0, 20, 5.0, 3.0, 1.0, 0.0, 0.47, 0.9, 0.02, 0.7, 101.0)
print('Finished creating all soil materials...')
# Out:
# Finished creating all soil materials...

# %%
ops.element('9_4_QuadUP', 1, 1, 3, 9, 7, 2, 6, 8, 4, 5, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 2, 7, 9, 15, 13, 8, 12, 14, 10, 11, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 3, 13, 15, 21, 19, 14, 18, 20, 16, 17, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 4, 19, 21, 27, 25, 20, 24, 26, 22, 23, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 5, 25, 27, 33, 31, 26, 30, 32, 28, 29, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 6, 31, 33, 39, 37, 32, 36, 38, 34, 35, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 7, 37, 39, 45, 43, 38, 42, 44, 40, 41, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 8, 43, 45, 51, 49, 44, 48, 50, 46, 47, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 9, 49, 51, 57, 55, 50, 54, 56, 52, 53, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 10, 55, 57, 63, 61, 56, 60, 62, 58, 59, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 11, 61, 63, 69, 67, 62, 66, 68, 64, 65, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 12, 67, 69, 75, 73, 68, 72, 74, 70, 71, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 13, 73, 75, 81, 79, 74, 78, 80, 76, 77, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 14, 79, 81, 87, 85, 80, 84, 86, 82, 83, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 15, 85, 87, 93, 91, 86, 90, 92, 88, 89, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 16, 91, 93, 99, 97, 92, 96, 98, 94, 95, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 17, 97, 99, 105, 103, 98, 102, 104, 100, 101, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 18, 103, 105, 111, 109, 104, 108, 110, 106, 107, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 19, 109, 111, 117, 115, 110, 114, 116, 112, 113, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 20, 115, 117, 123, 121, 116, 120, 122, 118, 119, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 21, 121, 123, 129, 127, 122, 126, 128, 124, 125, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 22, 127, 129, 135, 133, 128, 132, 134, 130, 131, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 23, 133, 135, 141, 139, 134, 138, 140, 136, 137, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 24, 139, 141, 147, 145, 140, 144, 146, 142, 143, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 25, 145, 147, 153, 151, 146, 150, 152, 148, 149, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 26, 151, 153, 159, 157, 152, 156, 158, 154, 155, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 27, 157, 159, 165, 163, 158, 162, 164, 160, 161, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 28, 163, 165, 171, 169, 164, 168, 170, 166, 167, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 29, 169, 171, 177, 175, 170, 174, 176, 172, 173, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 30, 175, 177, 183, 181, 176, 180, 182, 178, 179, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 31, 181, 183, 189, 187, 182, 186, 188, 184, 185, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 32, 187, 189, 195, 193, 188, 192, 194, 190, 191, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 33, 193, 195, 201, 199, 194, 198, 200, 196, 197, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 34, 199, 201, 207, 205, 200, 204, 206, 202, 203, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 35, 205, 207, 213, 211, 206, 210, 212, 208, 209, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 36, 211, 213, 219, 217, 212, 216, 218, 214, 215, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 37, 217, 219, 225, 223, 218, 222, 224, 220, 221, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 38, 223, 225, 231, 229, 224, 228, 230, 226, 227, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 39, 229, 231, 237, 235, 230, 234, 236, 232, 233, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 40, 235, 237, 243, 241, 236, 240, 242, 238, 239, 1.0, 1, 6880000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 41, 241, 243, 249, 247, 242, 246, 248, 244, 245, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 42, 247, 249, 255, 253, 248, 252, 254, 250, 251, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 43, 253, 255, 261, 259, 254, 258, 260, 256, 257, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 44, 259, 261, 267, 265, 260, 264, 266, 262, 263, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 45, 265, 267, 273, 271, 266, 270, 272, 268, 269, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 46, 271, 273, 279, 277, 272, 276, 278, 274, 275, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 47, 277, 279, 285, 283, 278, 282, 284, 280, 281, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 48, 283, 285, 291, 289, 284, 288, 290, 286, 287, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 49, 289, 291, 297, 295, 290, 294, 296, 292, 293, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 50, 295, 297, 303, 301, 296, 300, 302, 298, 299, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 51, 301, 303, 309, 307, 302, 306, 308, 304, 305, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 52, 307, 309, 315, 313, 308, 312, 314, 310, 311, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 53, 313, 315, 321, 319, 314, 318, 320, 316, 317, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 54, 319, 321, 327, 325, 320, 324, 326, 322, 323, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 55, 325, 327, 333, 331, 326, 330, 332, 328, 329, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 56, 331, 333, 339, 337, 332, 336, 338, 334, 335, 1.0, 2, 5060000.0, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 57, 337, 339, 345, 343, 338, 342, 344, 340, 341, 1.0, 3, 5e-06, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 58, 343, 345, 351, 349, 344, 348, 350, 346, 347, 1.0, 3, 5e-06, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 59, 349, 351, 357, 355, 350, 354, 356, 352, 353, 1.0, 3, 5e-06, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
ops.element('9_4_QuadUP', 60, 355, 357, 363, 361, 356, 360, 362, 358, 359, 1.0, 3, 5e-06, 1.0, 1.0, 1.0, -0.1961607717680774, -9.80803858840387)
print('Finished creating all soil elements...')
ops.node(364, 0.0, 0.0)
ops.node(365, 0.0, 0.0)
ops.fix(364, 1, 1)
ops.fix(365, 0, 1)
ops.equalDOF(1, 365, 1)
print('Finished creating dashpot nodes and boundary conditions...')
ops.uniaxialMaterial('Viscous', 4, 3500.0, 1)
ops.element('zeroLength', 61, 364, 365, '-mat', 4, '-dir', 1)
# Out:
# Finished creating all soil elements...
# Finished creating dashpot nodes and boundary conditions...

# %%
opst.vis.plotly.plot_model(show_node_numbering=False, show_ele_numbering=True, show_nodal_loads = False)

# %%
ops.recorder('Node', '-file', 'Gdisplacement.out', '-time', '-node', '-dof', 1, 2, 'disp')
ops.recorder('Node', '-file', 'Gacceleration.out', '-time', '-node', '-dof', 1, 2, 'accel')
ops.recorder('Node', '-file', 'GporePressure.out', '-time', '-node', '-dof', 3, 'vel')
ops.recorder('Element', '-file', 'bGstress1.out', '-time', '-eleRange', 1, 60, 'material', 1, 'stress')
ops.recorder('Element', '-file', 'bGstress2.out', '-time', '-eleRange', 1, 60, 'material', 2, 'stress')
ops.recorder('Element', '-file', 'bGstress3.out', '-time', '-eleRange', 1, 60, 'material', 3, 'stress')
ops.recorder('Element', '-file', 'bGstress4.out', '-time', '-eleRange', 1, 60, 'material', 4, 'stress')
ops.recorder('Element', '-file', 'bGstress9.out', '-time', '-eleRange', 1, 60, 'material', 9, 'stress')
ops.recorder('Element', '-file', 'bGstrain1.out', '-time', '-eleRange', 1, 60, 'material', 1, 'strain')
ops.recorder('Element', '-file', 'bGstrain2.out', '-time', '-eleRange', 1, 60, 'material', 2, 'strain')
ops.recorder('Element', '-file', 'bGstrain3.out', '-time', '-eleRange', 1, 60, 'material', 3, 'strain')
ops.recorder('Element', '-file', 'bGstrain4.out', '-time', '-eleRange', 1, 60, 'material', 4, 'strain')
ops.recorder('Element', '-file', 'bGstrain9.out', '-time', '-eleRange', 1, 60, 'material', 9, 'strain')
# Out:
# 350

# %%
ops.updateMaterialStage('-material', 1, '-stage', 0)
ops.updateMaterialStage('-material', 2, '-stage', 0)
ops.updateMaterialStage('-material', 3, '-stage', 0)
ops.constraints('Penalty', 100000000000000.0, 100000000000000.0)
ops.test('NormDispIncr', 0.0001, 35, 1)
ops.algorithm('KrylovNewton',)
ops.numberer('RCM',)
ops.system('ProfileSPD',)
ops.integrator('Newmark', 0.5, 0.25)
ops.analysis('Transient',)
ops.analyze(10, 500.0)
# Out:
# CTestNormDispIncr::test() - iteration: 1 current Norm: 425113 (max: 0.0001, Norm R: 0.601238)
# CTestNormDispIncr::test() - iteration: 2 current Norm: 0.133724 (max: 0.0001, Norm R: 0.531521)
# CTestNormDispIncr::test() - iteration: 3 current Norm: 0.00047453 (max: 0.0001, Norm R: 0.506252)
# CTestNormDispIncr::test() - iteration: 4 current Norm: 7.26456e-09 (max: 0.0001, Norm R: 0.483552)
#
# CTestNormDispIncr::test() - iteration: 1 current Norm: 850222 (max: 0.0001, Norm R: 1.76386)
# CTestNormDispIncr::test() - iteration: 2 current Norm: 0.26698 (max: 0.0001, Norm R: 1.80929)
# CTestNormDispIncr::test() - iteration: 3 current Norm: 0.000947411 (max: 0.0001, Norm R: 1.81607)
# CTestNormDispIncr::test() - iteration: 4 current Norm: 2.79877e-09 (max: 0.0001, Norm R: 1.90142)
#
# CTestNormDispIncr::test() - iteration: 1 current Norm: 850222 (max: 0.0001, Norm R: 2.45958)
# CTestNormDispIncr::test() - iteration: 2 current Norm: 0.26698 (max: 0.0001, Norm R: 2.32322)
# ...

# %%
print('Finished with elastic gravity analysis...')
ops.updateMaterialStage('-material', 1, '-stage', 1)
ops.updateMaterialStage('-material', 2, '-stage', 1)
ops.updateMaterialStage('-material', 3, '-stage', 1)
ODB = opst.post.CreateODB(
    odb_tag=22,
    compute_mechanical_measures=True,
    project_gauss_to_nodes="copy",  # "extrapolate", "copy", "average"
)
for _ in range(40):
    ops.analyze(1, 0.05)
    ODB.fetch_response_step()
ODB.save_response(zlib=True)
# Out:
# CTestNormDispIncr::test() - iteration: 1 current Norm: 85.0219 (max: 0.0001, Norm R: 7.90719)
# CTestNormDispIncr::test() - iteration: 2 current Norm: 0.000115999 (max: 0.0001, Norm R: 8.65276)
# CTestNormDispIncr::test() - iteration: 3 current Norm: 0.000196978 (max: 0.0001, Norm R: 7.99309)
# CTestNormDispIncr::test() - iteration: 4 current Norm: 2.42988e-05 (max: 0.0001, Norm R: 7.14235)
# Finished with elastic gravity analysis...
# CTestNormDispIncr::test() - iteration: 1 current Norm: 85.0223 (max: 0.0001, Norm R: 7.60666)
# CTestNormDispIncr::test() - iteration: 2 current Norm: 0.00020559 (max: 0.0001, Norm R: 52.087)
# CTestNormDispIncr::test() - iteration: 3 current Norm: 0.00411131 (max: 0.0001, Norm R: 21.8221)
# CTestNormDispIncr::test() - iteration: 4 current Norm: 0.00151744 (max: 0.0001, Norm R: 12.1494)
# CTestNormDispIncr::test() - iteration: 5 current Norm: 4.14836e-05 (max: 0.0001, Norm R: 7.7577)
#
# ...

# %%
ops.parameter(10001, 'element', 1, 'vPerm')
ops.parameter(10002, 'element', 1, 'hPerm')
ops.parameter(10003, 'element', 2, 'vPerm')
ops.parameter(10004, 'element', 2, 'hPerm')
ops.parameter(10005, 'element', 3, 'vPerm')
ops.parameter(10006, 'element', 3, 'hPerm')
ops.parameter(10007, 'element', 4, 'vPerm')
ops.parameter(10008, 'element', 4, 'hPerm')
ops.parameter(10009, 'element', 5, 'vPerm')
ops.parameter(10010, 'element', 5, 'hPerm')
ops.parameter(10011, 'element', 6, 'vPerm')
ops.parameter(10012, 'element', 6, 'hPerm')
ops.parameter(10013, 'element', 7, 'vPerm')
ops.parameter(10014, 'element', 7, 'hPerm')
ops.parameter(10015, 'element', 8, 'vPerm')
ops.parameter(10016, 'element', 8, 'hPerm')
ops.parameter(10017, 'element', 9, 'vPerm')
ops.parameter(10018, 'element', 9, 'hPerm')
ops.parameter(10019, 'element', 10, 'vPerm')
ops.parameter(10020, 'element', 10, 'hPerm')
ops.parameter(10021, 'element', 11, 'vPerm')
ops.parameter(10022, 'element', 11, 'hPerm')
ops.parameter(10023, 'element', 12, 'vPerm')
ops.parameter(10024, 'element', 12, 'hPerm')
ops.parameter(10025, 'element', 13, 'vPerm')
ops.parameter(10026, 'element', 13, 'hPerm')
ops.parameter(10027, 'element', 14, 'vPerm')
ops.parameter(10028, 'element', 14, 'hPerm')
ops.parameter(10029, 'element', 15, 'vPerm')
ops.parameter(10030, 'element', 15, 'hPerm')
ops.parameter(10031, 'element', 16, 'vPerm')
ops.parameter(10032, 'element', 16, 'hPerm')
ops.parameter(10033, 'element', 17, 'vPerm')
ops.parameter(10034, 'element', 17, 'hPerm')
ops.parameter(10035, 'element', 18, 'vPerm')
ops.parameter(10036, 'element', 18, 'hPerm')
ops.parameter(10037, 'element', 19, 'vPerm')
ops.parameter(10038, 'element', 19, 'hPerm')
ops.parameter(10039, 'element', 20, 'vPerm')
ops.parameter(10040, 'element', 20, 'hPerm')
ops.parameter(10041, 'element', 21, 'vPerm')
ops.parameter(10042, 'element', 21, 'hPerm')
ops.parameter(10043, 'element', 22, 'vPerm')
ops.parameter(10044, 'element', 22, 'hPerm')
ops.parameter(10045, 'element', 23, 'vPerm')
ops.parameter(10046, 'element', 23, 'hPerm')
ops.parameter(10047, 'element', 24, 'vPerm')
ops.parameter(10048, 'element', 24, 'hPerm')
ops.parameter(10049, 'element', 25, 'vPerm')
ops.parameter(10050, 'element', 25, 'hPerm')
ops.parameter(10051, 'element', 26, 'vPerm')
ops.parameter(10052, 'element', 26, 'hPerm')
ops.parameter(10053, 'element', 27, 'vPerm')
ops.parameter(10054, 'element', 27, 'hPerm')
ops.parameter(10055, 'element', 28, 'vPerm')
ops.parameter(10056, 'element', 28, 'hPerm')
ops.parameter(10057, 'element', 29, 'vPerm')
ops.parameter(10058, 'element', 29, 'hPerm')
ops.parameter(10059, 'element', 30, 'vPerm')
ops.parameter(10060, 'element', 30, 'hPerm')
ops.parameter(10061, 'element', 31, 'vPerm')
ops.parameter(10062, 'element', 31, 'hPerm')
ops.parameter(10063, 'element', 32, 'vPerm')
ops.parameter(10064, 'element', 32, 'hPerm')
ops.parameter(10065, 'element', 33, 'vPerm')
ops.parameter(10066, 'element', 33, 'hPerm')
ops.parameter(10067, 'element', 34, 'vPerm')
ops.parameter(10068, 'element', 34, 'hPerm')
ops.parameter(10069, 'element', 35, 'vPerm')
ops.parameter(10070, 'element', 35, 'hPerm')
ops.parameter(10071, 'element', 36, 'vPerm')
ops.parameter(10072, 'element', 36, 'hPerm')
ops.parameter(10073, 'element', 37, 'vPerm')
ops.parameter(10074, 'element', 37, 'hPerm')
ops.parameter(10075, 'element', 38, 'vPerm')
ops.parameter(10076, 'element', 38, 'hPerm')
ops.parameter(10077, 'element', 39, 'vPerm')
ops.parameter(10078, 'element', 39, 'hPerm')
ops.parameter(10079, 'element', 40, 'vPerm')
ops.parameter(10080, 'element', 40, 'hPerm')
ops.parameter(10081, 'element', 41, 'vPerm')
ops.parameter(10082, 'element', 41, 'hPerm')
ops.parameter(10083, 'element', 42, 'vPerm')
ops.parameter(10084, 'element', 42, 'hPerm')
ops.parameter(10085, 'element', 43, 'vPerm')
ops.parameter(10086, 'element', 43, 'hPerm')
ops.parameter(10087, 'element', 44, 'vPerm')
ops.parameter(10088, 'element', 44, 'hPerm')
ops.parameter(10089, 'element', 45, 'vPerm')
ops.parameter(10090, 'element', 45, 'hPerm')
ops.parameter(10091, 'element', 46, 'vPerm')
ops.parameter(10092, 'element', 46, 'hPerm')
ops.parameter(10093, 'element', 47, 'vPerm')
ops.parameter(10094, 'element', 47, 'hPerm')
ops.parameter(10095, 'element', 48, 'vPerm')
ops.parameter(10096, 'element', 48, 'hPerm')
ops.parameter(10097, 'element', 49, 'vPerm')
ops.parameter(10098, 'element', 49, 'hPerm')
ops.parameter(10099, 'element', 50, 'vPerm')
ops.parameter(10100, 'element', 50, 'hPerm')
ops.parameter(10101, 'element', 51, 'vPerm')
ops.parameter(10102, 'element', 51, 'hPerm')
ops.parameter(10103, 'element', 52, 'vPerm')
ops.parameter(10104, 'element', 52, 'hPerm')
ops.parameter(10105, 'element', 53, 'vPerm')
ops.parameter(10106, 'element', 53, 'hPerm')
ops.parameter(10107, 'element', 54, 'vPerm')
ops.parameter(10108, 'element', 54, 'hPerm')
ops.parameter(10109, 'element', 55, 'vPerm')
ops.parameter(10110, 'element', 55, 'hPerm')
ops.parameter(10111, 'element', 56, 'vPerm')
ops.parameter(10112, 'element', 56, 'hPerm')
ops.parameter(10113, 'element', 57, 'vPerm')
ops.parameter(10114, 'element', 57, 'hPerm')
ops.parameter(10115, 'element', 58, 'vPerm')
ops.parameter(10116, 'element', 58, 'hPerm')
ops.parameter(10117, 'element', 59, 'vPerm')
ops.parameter(10118, 'element', 59, 'hPerm')
ops.parameter(10119, 'element', 60, 'vPerm')
ops.parameter(10120, 'element', 60, 'hPerm')
ops.updateParameter(10001, 0.0001)
ops.updateParameter(10002, 0.0001)
ops.updateParameter(10003, 0.0001)
ops.updateParameter(10004, 0.0001)
ops.updateParameter(10005, 0.0001)
ops.updateParameter(10006, 0.0001)
ops.updateParameter(10007, 0.0001)
ops.updateParameter(10008, 0.0001)
ops.updateParameter(10009, 0.0001)
ops.updateParameter(10010, 0.0001)
ops.updateParameter(10011, 0.0001)
ops.updateParameter(10012, 0.0001)
ops.updateParameter(10013, 0.0001)
ops.updateParameter(10014, 0.0001)
ops.updateParameter(10015, 0.0001)
ops.updateParameter(10016, 0.0001)
ops.updateParameter(10017, 0.0001)
ops.updateParameter(10018, 0.0001)
ops.updateParameter(10019, 0.0001)
ops.updateParameter(10020, 0.0001)
ops.updateParameter(10021, 0.0001)
ops.updateParameter(10022, 0.0001)
ops.updateParameter(10023, 0.0001)
ops.updateParameter(10024, 0.0001)
ops.updateParameter(10025, 0.0001)
ops.updateParameter(10026, 0.0001)
ops.updateParameter(10027, 0.0001)
ops.updateParameter(10028, 0.0001)
ops.updateParameter(10029, 0.0001)
ops.updateParameter(10030, 0.0001)
ops.updateParameter(10031, 0.0001)
ops.updateParameter(10032, 0.0001)
ops.updateParameter(10033, 0.0001)
ops.updateParameter(10034, 0.0001)
ops.updateParameter(10035, 0.0001)
ops.updateParameter(10036, 0.0001)
ops.updateParameter(10037, 0.0001)
ops.updateParameter(10038, 0.0001)
ops.updateParameter(10039, 0.0001)
ops.updateParameter(10040, 0.0001)
ops.updateParameter(10041, 0.0001)
ops.updateParameter(10042, 0.0001)
ops.updateParameter(10043, 0.0001)
ops.updateParameter(10044, 0.0001)
ops.updateParameter(10045, 0.0001)
ops.updateParameter(10046, 0.0001)
ops.updateParameter(10047, 0.0001)
ops.updateParameter(10048, 0.0001)
ops.updateParameter(10049, 0.0001)
ops.updateParameter(10050, 0.0001)
ops.updateParameter(10051, 0.0001)
ops.updateParameter(10052, 0.0001)
ops.updateParameter(10053, 0.0001)
ops.updateParameter(10054, 0.0001)
ops.updateParameter(10055, 0.0001)
ops.updateParameter(10056, 0.0001)
ops.updateParameter(10057, 0.0001)
ops.updateParameter(10058, 0.0001)
ops.updateParameter(10059, 0.0001)
ops.updateParameter(10060, 0.0001)
ops.updateParameter(10061, 0.0001)
ops.updateParameter(10062, 0.0001)
ops.updateParameter(10063, 0.0001)
ops.updateParameter(10064, 0.0001)
ops.updateParameter(10065, 0.0001)
ops.updateParameter(10066, 0.0001)
ops.updateParameter(10067, 0.0001)
ops.updateParameter(10068, 0.0001)
ops.updateParameter(10069, 0.0001)
ops.updateParameter(10070, 0.0001)
ops.updateParameter(10071, 0.0001)
ops.updateParameter(10072, 0.0001)
ops.updateParameter(10073, 0.0001)
ops.updateParameter(10074, 0.0001)
ops.updateParameter(10075, 0.0001)
ops.updateParameter(10076, 0.0001)
ops.updateParameter(10077, 0.0001)
ops.updateParameter(10078, 0.0001)
ops.updateParameter(10079, 0.0001)
ops.updateParameter(10080, 0.0001)
ops.updateParameter(10081, 0.0001)
ops.updateParameter(10082, 0.0001)
ops.updateParameter(10083, 0.0001)
ops.updateParameter(10084, 0.0001)
ops.updateParameter(10085, 0.0001)
ops.updateParameter(10086, 0.0001)
ops.updateParameter(10087, 0.0001)
ops.updateParameter(10088, 0.0001)
ops.updateParameter(10089, 0.0001)
ops.updateParameter(10090, 0.0001)
ops.updateParameter(10091, 0.0001)
ops.updateParameter(10092, 0.0001)
ops.updateParameter(10093, 0.0001)
ops.updateParameter(10094, 0.0001)
ops.updateParameter(10095, 0.0001)
ops.updateParameter(10096, 0.0001)
ops.updateParameter(10097, 0.0001)
ops.updateParameter(10098, 0.0001)
ops.updateParameter(10099, 0.0001)
ops.updateParameter(10100, 0.0001)
ops.updateParameter(10101, 0.0001)
ops.updateParameter(10102, 0.0001)
ops.updateParameter(10103, 0.0001)
ops.updateParameter(10104, 0.0001)
ops.updateParameter(10105, 0.0001)
ops.updateParameter(10106, 0.0001)
ops.updateParameter(10107, 0.0001)
ops.updateParameter(10108, 0.0001)
ops.updateParameter(10109, 0.0001)
ops.updateParameter(10110, 0.0001)
ops.updateParameter(10111, 0.0001)
ops.updateParameter(10112, 0.0001)
ops.updateParameter(10113, 0.0001)
ops.updateParameter(10114, 0.0001)
ops.updateParameter(10115, 0.0001)
ops.updateParameter(10116, 0.0001)
ops.updateParameter(10117, 0.0001)
ops.updateParameter(10118, 0.0001)
ops.updateParameter(10119, 0.0001)
ops.updateParameter(10120, 0.0001)
print('Finished updating permeabilities for dynamic analysis...')
# Out:
# Finished updating permeabilities for dynamic analysis...

# %%
ops.setTime(0.0,)
ops.wipeAnalysis()
ops.remove('recorders',)
ops.recorder('Node', '-file', 'displacement.out', '-time', '-dT', 0.05, '-node', '-dof', 1, 2, 'disp')
ops.recorder('Node', '-file', 'acceleration.out', '-time', '-dT', 0.05, '-node', '-dof', 1, 2, 'accel')
ops.recorder('Node', '-file', 'porePressure.out', '-time', '-dT', 0.05, '-node', '-dof', 3, 'vel')
ops.recorder('Element', '-file', 'cstress1.out', '-time', '-dT', 0.05, '-eleRange', 1, 60, 'material', 1, 'stress')
ops.recorder('Element', '-file', 'cstress2.out', '-time', '-dT', 0.05, '-eleRange', 1, 60, 'material', 2, 'stress')
ops.recorder('Element', '-file', 'cstress3.out', '-time', '-dT', 0.05, '-eleRange', 1, 60, 'material', 3, 'stress')
ops.recorder('Element', '-file', 'cstress4.out', '-time', '-dT', 0.05, '-eleRange', 1, 60, 'material', 4, 'stress')
ops.recorder('Element', '-file', 'cstress9.out', '-time', '-dT', 0.05, '-eleRange', 1, 60, 'material', 9, 'stress')
ops.recorder('Element', '-file', 'cstrain1.out', '-time', '-dT', 0.05, '-eleRange', 1, 60, 'material', 1, 'strain')
ops.recorder('Element', '-file', 'cstrain2.out', '-time', '-dT', 0.05, '-eleRange', 1, 60, 'material', 2, 'strain')
ops.recorder('Element', '-file', 'cstrain3.out', '-time', '-dT', 0.05, '-eleRange', 1, 60, 'material', 3, 'strain')
ops.recorder('Element', '-file', 'cstrain4.out', '-time', '-dT', 0.05, '-eleRange', 1, 60, 'material', 4, 'strain')
ops.recorder('Element', '-file', 'cstrain9.out', '-time', '-dT', 0.05, '-eleRange', 1, 60, 'material', 9, 'strain')
print('Finished creating all recorders...')
ops.model('BasicBuilder', '-ndm', 2, '-ndf', 3)
ops.timeSeries('Path', 10, '-dt', 0.005, '-filePath', 'velocityHistory.txt', '-factor', 3500.0)
ops.pattern('Plain', 10, 10)
ops.load(1, 1.0, 0.0, 0.0)
print('Dynamic loading created...')
ops.constraints('Penalty', 1e+16, 1e+16)
ops.test('NormDispIncr', 0.001, 35, 1)
ops.algorithm('KrylovNewton',)
ops.numberer('RCM',)
ops.system('ProfileSPD',)
ops.integrator('Newmark', 0.5, 0.25)
ops.rayleigh(0.04976780441980199, 0.00031515830311111683, 0.0, 0.0)
ops.analysis('Transient',)
# Out:
# Finished creating all recorders...
# Dynamic loading created...

# %%
# --- Parameters (you must define these based on your model)
motion_dt = 0.005
motion_steps = 7990
vs_max = 250.0
s_elem_y = [0.05, 0.5, 1.0]  # Example element sizes per layer (update as needed)

# --- Derived parameters
duration = motion_dt * motion_steps
min_size = min(s_elem_y)
k_trial = min_size / (vs_max ** 0.5)
if motion_dt <= k_trial:
    n_steps = motion_steps
    d_t = motion_dt
else:
    n_steps = int(duration / k_trial) + 1
    d_t = duration / n_steps

# --- Begin analysis with time tracking
startT = tt.time()
ok = ops.analyze(n_steps, d_t)

if ok != 0:
    print("Did not converge, reducing time step")
    cur_time = ops.getTime()
    m_time = cur_time
    cur_step = cur_time / d_t
    r_step = (n_steps - cur_step) * 2.0
    rem_step = int(r_step)
    d_t /= 2.0

    ok = ops.analyze(rem_step, d_t)

    if ok != 0:
        print("Still did not converge, reducing time step again")
        cur_time = ops.getTime()
        cur_step = (cur_time - m_time) / d_t
        rem_step = int((r_step - cur_step) * 2.0)
        d_t /= 2.0
        ops.analyze(rem_step, d_t)

endT = tt.time()
print("Finished with dynamic analysis...")
print(f"Analysis execution time: {endT - startT:.2f} seconds")

ops.wipe()
# Out:
# CTestNormDispIncr::test() - iteration: 1 current Norm: 5.37689 (max: 0.001, Norm R: 705.459)
# CTestNormDispIncr::test() - iteration: 2 current Norm: 6.89841e-06 (max: 0.001, Norm R: 631.399)
#
# CTestNormDispIncr::test() - iteration: 1 current Norm: 5.37676 (max: 0.001, Norm R: 566.458)
# CTestNormDispIncr::test() - iteration: 2 current Norm: 3.39424e-08 (max: 0.001, Norm R: 554.889)
#
# CTestNormDispIncr::test() - iteration: 1 current Norm: 5.37684 (max: 0.001, Norm R: 604.905)
# CTestNormDispIncr::test() - iteration: 2 current Norm: 2.38246e-08 (max: 0.001, Norm R: 549.234)
#
# CTestNormDispIncr::test() - iteration: 1 current Norm: 5.37712 (max: 0.001, Norm R: 590.732)
# CTestNormDispIncr::test() - iteration: 2 current Norm: 1.47471e-08 (max: 0.001, Norm R: 576.983)
#
# CTestNormDispIncr::test() - iteration: 1 current Norm: 5.3775 (max: 0.001, Norm R: 588.217)
# CTestNormDispIncr::test() - iteration: 2 current Norm: 9.75936e-09 (max: 0.001, Norm R: 579.657)
#
# ...
